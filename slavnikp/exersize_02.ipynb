C(=O)Nc1nc2ccc(-c3ccnc(NS(=O)(=O)c4ccccc4F)n3...          IC50
# 1        CC(=O)Nc1nc2ccc(-c3ccnc(OCc4cccc(C)c4)n3)cc2s1          IC50
# 2       COc1cccc(COc2nccc(-c3ccc4nc(NC(C)=O)sc4c3)n2)c1          IC50
# 3     CC(=O)Nc1nc2ccc(-c3ccnc(NS(=O)(=O)c4ccc(F)cc4)...          IC50
# 4     CC(=O)Nc1nc2ccc(-c3ccnc(N(C)S(=O)(=O)c4ccccc4F...          IC50
# ...                                                 ...           ...
# 4591  COc1ncc(-c2ccc3nccc(=O)n3c2)cc1NS(=O)(=O)c1ccc...          IC50
# 4592  O=c1ccnc2ccc(-c3cnc(Cl)c(NS(=O)(=O)c4ccc(F)cc4...          IC50
# 4593  C=CC(=O)Nc1ccc(-n2c(=O)ccc3oc4ccc(-c5cccnc5)cc...          IC50
# 4594        COc1ccc(-c2ccc3c(N4CCOCC4)nc(CN)nc3n2)cc1CO          IC50
# 4595               CC(=O)n1nc(C)c(-c2ccc(Cl)c(Cl)c2)c1N          IC50
#
#      Standard Relation  ...  Target ChEMBL ID  \
# 0                  '='  ...        CHEMBL2842
# 1                  '>'  ...        CHEMBL2842
# 2                  '>'  ...        CHEMBL2842
# 3                  '='  ...        CHEMBL2842
# 4                  '>'  ...        CHEMBL2842
# ...                ...  ...               ...
# 4591               '>'  ...        CHEMBL2842
# 4592               '>'  ...        CHEMBL2842
# 4593               '='  ...        CHEMBL2842
# 4594               '='  ...        CHEMBL2842
# 4595               '>'  ...        CHEMBL2842
#
#                                Target Name  Target Organism     Target Type  \
# 0     Serine/threonine-protein kinase mTOR     Homo sapiens  SINGLE PROTEIN
# 1     Serine/threonine-protein kinase mTOR     Homo sapiens  SINGLE PROTEIN
# 2     Serine/threonine-protein kinase mTOR     Homo sapiens  SINGLE PROTEIN
# 3     Serine/threonine-protein kinase mTOR     Homo sapiens  SINGLE PROTEIN
# 4     Serine/threonine-protein kinase mTOR     Homo sapiens  SINGLE PROTEIN
# ...                                    ...              ...             ...
# 4591  Serine/threonine-protein kinase mTOR     Homo sapiens  SINGLE PROTEIN
# 4592  Serine/threonine-protein kinase mTOR     Homo sapiens  SINGLE PROTEIN
# 4593  Serine/threonine-protein kinase mTOR     Homo sapiens  SINGLE PROTEIN
# 4594  Serine/threonine-protein kinase mTOR     Homo sapiens  SINGLE PROTEIN
# 4595  Serine/threonine-protein kinase mTOR     Homo sapiens  SINGLE PROTEIN
#
#      Document ChEMBL ID Source ID     Source Description   Document Journal  \
# 0         CHEMBL1773016         1  Scientific Literature      J. Med. Chem.
# 1         CHEMBL1773016         1  Scientific Literature      J. Med. Chem.
# 2         CHEMBL1773016         1  Scientific Literature      J. Med. Chem.
# 3         CHEMBL1773016         1  Scientific Literature      J. Med. Chem.
# 4         CHEMBL1773016         1  Scientific Literature      J. Med. Chem.
# ...                 ...       ...                    ...                ...
# 4591      CHEMBL4251704         1  Scientific Literature  ACS Med Chem Lett
# 4592      CHEMBL4251704         1  Scientific Literature  ACS Med Chem Lett
# 4593      CHEMBL4229497         1  Scientific Literature    Bioorg Med Chem
# 4594      CHEMBL4229417         1  Scientific Literature    Bioorg Med Chem
# 4595      CHEMBL4257503         1  Scientific Literature        MedChemComm
#
#       Document Year  Cell ChEMBL ID
# 0              2011             NaN
# 1              2011             NaN
# 2              2011             NaN
# 3              2011             NaN
# 4              2011             NaN
# ...             ...             ...
# 4591           2018             NaN
# 4592           2018             NaN
# 4593           2018             NaN
# 4594           2018             NaN
# 4595           2018             NaN
#
# [4596 rows x 41 columns]

# %%
mtor_red = mtor[['Molecule ChEMBL ID', 'Smiles']]

# %%
mtor_red
# Out:
#      Molecule ChEMBL ID                                             Smiles
# 0         CHEMBL1773577  CC(=O)Nc1nc2ccc(-c3ccnc(NS(=O)(=O)c4ccccc4F)n3...
# 1         CHEMBL1773561     CC(=O)Nc1nc2ccc(-c3ccnc(OCc4cccc(C)c4)n3)cc2s1
# 2         CHEMBL1773077    COc1cccc(COc2nccc(-c3ccc4nc(NC(C)=O)sc4c3)n2)c1
# 3         CHEMBL1773580  CC(=O)Nc1nc2ccc(-c3ccnc(NS(=O)(=O)c4ccc(F)cc4)...
# 4         CHEMBL1773578  CC(=O)Nc1nc2ccc(-c3ccnc(N(C)S(=O)(=O)c4ccccc4F...
# ...                 ...                                                ...
# 4591      CHEMBL4287809  COc1ncc(-c2ccc3nccc(=O)n3c2)cc1NS(=O)(=O)c1ccc...
# 4592      CHEMBL4280265  O=c1ccnc2ccc(-c3cnc(Cl)c(NS(=O)(=O)c4ccc(F)cc4...
# 4593      CHEMBL4246563  C=CC(=O)Nc1ccc(-n2c(=O)ccc3oc4ccc(-c5cccnc5)cc...
# 4594      CHEMBL4244147        COc1ccc(-c2ccc3c(N4CCOCC4)nc(CN)nc3n2)cc1CO
# 4595      CHEMBL4276946               CC(=O)n1nc(C)c(-c2ccc(Cl)c(Cl)c2)c1N
#
# [4596 rows x 2 columns]

# %%
mtor_red['Mol'] = mtor_red.apply(lambda row: Chem.MolFromSmiles(row[1]), axis=1)

# %%
mtor_red
# Out:
#      Molecule ChEMBL ID                                             Smiles  \
# 0         CHEMBL1773577  CC(=O)Nc1nc2ccc(-c3ccnc(NS(=O)(=O)c4ccccc4F)n3...
# 1         CHEMBL1773561     CC(=O)Nc1nc2ccc(-c3ccnc(OCc4cccc(C)c4)n3)cc2s1
# 2         CHEMBL1773077    COc1cccc(COc2nccc(-c3ccc4nc(NC(C)=O)sc4c3)n2)c1
# 3         CHEMBL1773580  CC(=O)Nc1nc2ccc(-c3ccnc(NS(=O)(=O)c4ccc(F)cc4)...
# 4         CHEMBL1773578  CC(=O)Nc1nc2ccc(-c3ccnc(N(C)S(=O)(=O)c4ccccc4F...
# ...                 ...                                                ...
# 4591      CHEMBL4287809  COc1ncc(-c2ccc3nccc(=O)n3c2)cc1NS(=O)(=O)c1ccc...
# 4592      CHEMBL4280265  O=c1ccnc2ccc(-c3cnc(Cl)c(NS(=O)(=O)c4ccc(F)cc4...
# 4593      CHEMBL4246563  C=CC(=O)Nc1ccc(-n2c(=O)ccc3oc4ccc(-c5cccnc5)cc...
# 4594      CHEMBL4244147        COc1ccc(-c2ccc3c(N4CCOCC4)nc(CN)nc3n2)cc1CO
# 4595      CHEMBL4276946               CC(=O)n1nc(C)c(-c2ccc(Cl)c(Cl)c2)c1N
#
#                                                     Mol
# 0     <rdkit.Chem.rdchem.Mol object at 0x000001E2FEB...
# 1     <rdkit.Chem.rdchem.Mol object at 0x000001E2FEB...
# 2     <rdkit.Chem.rdchem.Mol object at 0x000001E2FEB...
# 3     <rdkit.Chem.rdchem.Mol object at 0x000001E2FEB...
# 4     <rdkit.Chem.rdchem.Mol object at 0x000001E2FEB...
# ...                                                 ...
# 4591  <rdkit.Chem.rdchem.Mol object at 0x000001E2FEC...
# 4592  <rdkit.Chem.rdchem.Mol object at 0x000001E2FEC...
# 4593  <rdkit.Chem.rdchem.Mol object at 0x000001E2FEC...
# 4594  <rdkit.Chem.rdchem.Mol object at 0x000001E2FEC...
# 4595  <rdkit.Chem.rdchem.Mol object at 0x000001E2FEC...
#
# [4596 rows x 3 columns]

# %%
mtor_red['Source'] = 'mtor'

# %%
mtor_red
# Out:
#      Molecule ChEMBL ID                                             Smiles  \
# 0         CHEMBL1773577  CC(=O)Nc1nc2ccc(-c3ccnc(NS(=O)(=O)c4ccccc4F)n3...
# 1         CHEMBL1773561     CC(=O)Nc1nc2ccc(-c3ccnc(OCc4cccc(C)c4)n3)cc2s1
# 2         CHEMBL1773077    COc1cccc(COc2nccc(-c3ccc4nc(NC(C)=O)sc4c3)n2)c1
# 3         CHEMBL1773580  CC(=O)Nc1nc2ccc(-c3ccnc(NS(=O)(=O)c4ccc(F)cc4)...
# 4         CHEMBL1773578  CC(=O)Nc1nc2ccc(-c3ccnc(N(C)S(=O)(=O)c4ccccc4F...
# ...                 ...                                                ...
# 4591      CHEMBL4287809  COc1ncc(-c2ccc3nccc(=O)n3c2)cc1NS(=O)(=O)c1ccc...
# 4592      CHEMBL4280265  O=c1ccnc2ccc(-c3cnc(Cl)c(NS(=O)(=O)c4ccc(F)cc4...
# 4593      CHEMBL4246563  C=CC(=O)Nc1ccc(-n2c(=O)ccc3oc4ccc(-c5cccnc5)cc...
# 4594      CHEMBL4244147        COc1ccc(-c2ccc3c(N4CCOCC4)nc(CN)nc3n2)cc1CO
# 4595      CHEMBL4276946               CC(=O)n1nc(C)c(-c2ccc(Cl)c(Cl)c2)c1N
#
#                                                     Mol Source
# 0     <rdkit.Chem.rdchem.Mol object at 0x000001E2FEB...   mtor
# 1     <rdkit.Chem.rdchem.Mol object at 0x000001E2FEB...   mtor
# 2     <rdkit.Chem.rdchem.Mol object at 0x000001E2FEB...   mtor
# 3     <rdkit.Chem.rdchem.Mol object at 0x000001E2FEB...   mtor
# 4     <rdkit.Chem.rdchem.Mol object at 0x000001E2FEB...   mtor
# ...                                                 ...    ...
# 4591  <rdkit.Chem.rdchem.Mol object at 0x000001E2FEC...   mtor
# 4592  <rdkit.Chem.rdchem.Mol object at 0x000001E2FEC...   mtor
# 4593  <rdkit.Chem.rdchem.Mol object at 0x000001E2FEC...   mtor
# 4594  <rdkit.Chem.rdchem.Mol object at 0x000001E2FEC...   mtor
# 4595  <rdkit.Chem.rdchem.Mol object at 0x000001E2FEC...   mtor
#
# [4596 rows x 4 columns]

# %%
drugb = pd.DataFrame(drugbank, columns=['Mol'])

# %%
drugb['Smiles'] = drugb.apply(lambda row: Chem.MolToSmiles(row['Mol']), axis=1)

# %%
drugb['Source'] = 'drugbank'

# %%
drugb['Mol'][0]

# %%
drugb['Molecule ChEMBL ID'] = drugb.apply(lambda row: row['Mol'].GetProp('DATABASE_ID'), axis=1)

# %%
drugb
# Out:
#                                                     Mol  \
# 0     <rdkit.Chem.rdchem.Mol object at 0x000001E2F2B...
# 1     <rdkit.Chem.rdchem.Mol object at 0x000001E2F2B...
# 2     <rdkit.Chem.rdchem.Mol object at 0x000001E2F2B...
# 3     <rdkit.Chem.rdchem.Mol object at 0x000001E2F2B...
# 4     <rdkit.Chem.rdchem.Mol object at 0x000001E2F2B...
# ...                                                 ...
# 7115  <rdkit.Chem.rdchem.Mol object at 0x000001E2F2C...
# 7116  <rdkit.Chem.rdchem.Mol object at 0x000001E2F2C...
# 7117  <rdkit.Chem.rdchem.Mol object at 0x000001E2F2C...
# 7118  <rdkit.Chem.rdchem.Mol object at 0x000001E2F2C...
# 7119  <rdkit.Chem.rdchem.Mol object at 0x000001E2F2C...
#
#                                                  Smiles    Source  \
# 0     CC[C@H](C)[C@H](NC(=O)[C@H](CCC(=O)O)NC(=O)[C@...  drugbank
# 1     CC(C)C[C@H](NC(=O)[C@@H](COC(C)(C)C)NC(=O)[C@H...  drugbank
# 2     N=C(N)NCCC[C@H](NC(=O)[C@@H]1CCCN1C(=O)[C@@H]1...  drugbank
# 3     CC(=O)N[C@H](Cc1ccc2ccccc2c1)C(=O)N[C@H](Cc1cc...  drugbank
# 4     C/C=C/C[C@@H](C)[C@@H](O)[C@H]1C(=O)N[C@@H](CC...  drugbank
# ...                                                 ...       ...
# 7115                                      Oc1ccc(Cl)cc1  drugbank
# 7116  O=c1ccc2cc(O[C@@H]3O[C@H](CO)[C@@H](O)[C@H](O)...  drugbank
# 7117  CC(=O)Nc1ccc(C(=O)O)cc1.CC(=O)Nc1ccc(C(=O)O)cc...  drugbank
# 7118             CCCCCCCCCCCCOC(=O)CS(=O)(=O)[O-].[Na+]  drugbank
# 7119  C[C@H]1C[C@H]2[C@@H]3CCC4=CC(=O)C=C[C@]4(C)[C@...  drugbank
#
#      Molecule ChEMBL ID
# 0               DB00006
# 1               DB00014
# 2               DB00035
# 3               DB00050
# 4               DB00091
# ...                 ...
# 7115            DB13154
# 7116            DB13155
# 7117            DB13156
# 7118            DB13157
# 7119            DB13158
#
# [7120 rows x 4 columns]

# %%
drugb.rename({'Molecule ChEMBL ID':'ID'}, axis=1, inplace=True)

# %%
mtor_red.rename({'Molecule ChEMBL ID':'ID'}, axis=1, inplace=True)

# %%
drugb['MolWt'] = drugb.apply(lambda row: Descriptors.ExactMolWt(row['Mol']), axis=1)

# %%
mtor_red['MolWt'] = mtor_red.apply(lambda row: Descriptors.ExactMolWt(row['Mol']), axis=1)

# %%
drugb['NumAtoms'] = drugb.apply(lambda row: row['Mol'].GetNumAtoms(), axis=1)

# %%
mtor_red['NumAtoms'] = mtor_red.apply(lambda row: row['Mol'].GetNumAtoms(), axis=1)

# %%
drugb['LogP'] = drugb.apply(lambda row: Descriptors.MolLogP(row['Mol']), axis=1)

# %%
mtor_red['LogP'] = mtor_red.apply(lambda row: Descriptors.MolLogP(row['Mol']), axis=1)

# %%
drugb['NumHDonors'] = drugb.apply(lambda row: Descriptors.NumHDonors(row['Mol']), axis=1)

# %%
mtor_red['NumHDonors'] = mtor_red.apply(lambda row: Descriptors.NumHDonors(row['Mol']), axis=1)

# %%
drugb['NumHAcceptors'] = drugb.apply(lambda row: Descriptors.NumHAcceptors(row['Mol']), axis=1)

# %%
mtor_red['NumHAcceptors'] = mtor_red.apply(lambda row: Descriptors.NumHAcceptors(row['Mol']), axis=1)

# %%
drugb
# Out:
#                                                     Mol  \
# 0     <rdkit.Chem.rdchem.Mol object at 0x000001E2F2B...
# 1     <rdkit.Chem.rdchem.Mol object at 0x000001E2F2B...
# 2     <rdkit.Chem.rdchem.Mol object at 0x000001E2F2B...
# 3     <rdkit.Chem.rdchem.Mol object at 0x000001E2F2B...
# 4     <rdkit.Chem.rdchem.Mol object at 0x000001E2F2B...
# ...                                                 ...
# 7115  <rdkit.Chem.rdchem.Mol object at 0x000001E2F2C...
# 7116  <rdkit.Chem.rdchem.Mol object at 0x000001E2F2C...
# 7117  <rdkit.Chem.rdchem.Mol object at 0x000001E2F2C...
# 7118  <rdkit.Chem.rdchem.Mol object at 0x000001E2F2C...
# 7119  <rdkit.Chem.rdchem.Mol object at 0x000001E2F2C...
#
#                                                  Smiles    Source       ID  \
# 0     CC[C@H](C)[C@H](NC(=O)[C@H](CCC(=O)O)NC(=O)[C@...  drugbank  DB00006
# 1     CC(C)C[C@H](NC(=O)[C@@H](COC(C)(C)C)NC(=O)[C@H...  drugbank  DB00014
# 2     N=C(N)NCCC[C@H](NC(=O)[C@@H]1CCCN1C(=O)[C@@H]1...  drugbank  DB00035
# 3     CC(=O)N[C@H](Cc1ccc2ccccc2c1)C(=O)N[C@H](Cc1cc...  drugbank  DB00050
# 4     C/C=C/C[C@@H](C)[C@@H](O)[C@H]1C(=O)N[C@@H](CC...  drugbank  DB00091
# ...                                                 ...       ...      ...
# 7115                                      Oc1ccc(Cl)cc1  drugbank  DB13154
# 7116  O=c1ccc2cc(O[C@@H]3O[C@H](CO)[C@@H](O)[C@H](O)...  drugbank  DB13155
# 7117  CC(=O)Nc1ccc(C(=O)O)cc1.CC(=O)Nc1ccc(C(=O)O)cc...  drugbank  DB13156
# 7118             CCCCCCCCCCCCOC(=O)CS(=O)(=O)[O-].[Na+]  drugbank  DB13157
# 7119  C[C@H]1C[C@H]2[C@@H]3CCC4=CC(=O)C=C[C@]4(C)[C@...  drugbank  DB13158
#
#             MolWt  NumAtoms     LogP  NumHDonors  NumHAcceptors
# 0     2178.985813       155 -8.11643          28             29
# 1     1268.641439        91 -3.10570          17             16
# 2     1068.426955        74 -4.13203          14             15
# 3     1429.669818       102 -0.50613          17             16
# 4     1201.841368        85  3.26900           5             12
# ...           ...       ...      ...         ...            ...
# 7115   128.002892         8  2.04560           1              1
# 7116   340.079432        24 -1.32270           5              9
# 7117  1114.554641        79  1.54710          13             20
# 7118   330.147689        21 -0.00030           0              5
# 7119   408.150365        28  3.35040           1              4
#
# [7120 rows x 9 columns]

# %%
mtor_red
# Out:
#                  ID                                             Smiles  \
# 0     CHEMBL1773577  CC(=O)Nc1nc2ccc(-c3ccnc(NS(=O)(=O)c4ccccc4F)n3...
# 1     CHEMBL1773561     CC(=O)Nc1nc2ccc(-c3ccnc(OCc4cccc(C)c4)n3)cc2s1
# 2     CHEMBL1773077    COc1cccc(COc2nccc(-c3ccc4nc(NC(C)=O)sc4c3)n2)c1
# 3     CHEMBL1773580  CC(=O)Nc1nc2ccc(-c3ccnc(NS(=O)(=O)c4ccc(F)cc4)...
# 4     CHEMBL1773578  CC(=O)Nc1nc2ccc(-c3ccnc(N(C)S(=O)(=O)c4ccccc4F...
# ...             ...                                                ...
# 4591  CHEMBL4287809  COc1ncc(-c2ccc3nccc(=O)n3c2)cc1NS(=O)(=O)c1ccc...
# 4592  CHEMBL4280265  O=c1ccnc2ccc(-c3cnc(Cl)c(NS(=O)(=O)c4ccc(F)cc4...
# 4593  CHEMBL4246563  C=CC(=O)Nc1ccc(-n2c(=O)ccc3oc4ccc(-c5cccnc5)cc...
# 4594  CHEMBL4244147        COc1ccc(-c2ccc3c(N4CCOCC4)nc(CN)nc3n2)cc1CO
# 4595  CHEMBL4276946               CC(=O)n1nc(C)c(-c2ccc(Cl)c(Cl)c2)c1N
#
#                                                     Mol Source       MolWt  \
# 0     <rdkit.Chem.rdchem.Mol object at 0x000001E2FEB...   mtor  443.052210
# 1     <rdkit.Chem.rdchem.Mol object at 0x000001E2FEB...   mtor  390.115047
# 2     <rdkit.Chem.rdchem.Mol object at 0x000001E2FEB...   mtor  406.109961
# 3     <rdkit.Chem.rdchem.Mol object at 0x000001E2FEB...   mtor  443.052210
# 4     <rdkit.Chem.rdchem.Mol object at 0x000001E2FEB...   mtor  457.067860
# ...                                                 ...    ...         ...
# 4591  <rdkit.Chem.rdchem.Mol object at 0x000001E2FEC...   mtor  426.079804
# 4592  <rdkit.Chem.rdchem.Mol object at 0x000001E2FEC...   mtor  448.020845
# 4593  <rdkit.Chem.rdchem.Mol object at 0x000001E2FEC...   mtor  407.126991
# 4594  <rdkit.Chem.rdchem.Mol object at 0x000001E2FEC...   mtor  381.180090
# 4595  <rdkit.Chem.rdchem.Mol object at 0x000001E2FEC...   mtor  283.027917
#
#       NumAtoms     LogP  NumHDonors  NumHAcceptors
# 0           30  3.65160           2              7
# 1           28  4.59912           1              6
# 2           29  4.29930           1              7
# 3           30  3.65160           2              7
# 4           31  3.67590           1              7
# ...        ...      ...         ...            ...
# 4591        30  2.70500           1              7
# 4592        30  3.48890           1              6
# 4593        31  4.92340           1              5
# 4594        28  1.48800           2              8
# 4595        18  3.40762           1              4
#
# [4596 rows x 9 columns]

# %%
df = pd.concat([mtor_red, drugb], axis=0)

# %%
df
# Out:
#                  ID                                             Smiles  \
# 0     CHEMBL1773577  CC(=O)Nc1nc2ccc(-c3ccnc(NS(=O)(=O)c4ccccc4F)n3...
# 1     CHEMBL1773561     CC(=O)Nc1nc2ccc(-c3ccnc(OCc4cccc(C)c4)n3)cc2s1
# 2     CHEMBL1773077    COc1cccc(COc2nccc(-c3ccc4nc(NC(C)=O)sc4c3)n2)c1
# 3     CHEMBL1773580  CC(=O)Nc1nc2ccc(-c3ccnc(NS(=O)(=O)c4ccc(F)cc4)...
# 4     CHEMBL1773578  CC(=O)Nc1nc2ccc(-c3ccnc(N(C)S(=O)(=O)c4ccccc4F...
# ...             ...                                                ...
# 7115        DB13154                                      Oc1ccc(Cl)cc1
# 7116        DB13155  O=c1ccc2cc(O[C@@H]3O[C@H](CO)[C@@H](O)[C@H](O)...
# 7117        DB13156  CC(=O)Nc1ccc(C(=O)O)cc1.CC(=O)Nc1ccc(C(=O)O)cc...
# 7118        DB13157             CCCCCCCCCCCCOC(=O)CS(=O)(=O)[O-].[Na+]
# 7119        DB13158  C[C@H]1C[C@H]2[C@@H]3CCC4=CC(=O)C=C[C@]4(C)[C@...
#
#                                                     Mol    Source  \
# 0     <rdkit.Chem.rdchem.Mol object at 0x000001E2FEB...      mtor
# 1     <rdkit.Chem.rdchem.Mol object at 0x000001E2FEB...      mtor
# 2     <rdkit.Chem.rdchem.Mol object at 0x000001E2FEB...      mtor
# 3     <rdkit.Chem.rdchem.Mol object at 0x000001E2FEB...      mtor
# 4     <rdkit.Chem.rdchem.Mol object at 0x000001E2FEB...      mtor
# ...                                                 ...       ...
# 7115  <rdkit.Chem.rdchem.Mol object at 0x000001E2F2C...  drugbank
# 7116  <rdkit.Chem.rdchem.Mol object at 0x000001E2F2C...  drugbank
# 7117  <rdkit.Chem.rdchem.Mol object at 0x000001E2F2C...  drugbank
# 7118  <rdkit.Chem.rdchem.Mol object at 0x000001E2F2C...  drugbank
# 7119  <rdkit.Chem.rdchem.Mol object at 0x000001E2F2C...  drugbank
#
#             MolWt  NumAtoms     LogP  NumHDonors  NumHAcceptors
# 0      443.052210        30  3.65160           2              7
# 1      390.115047        28  4.59912           1              6
# 2      406.109961        29  4.29930           1              7
# 3      443.052210        30  3.65160           2              7
# 4      457.067860        31  3.67590           1              7
# ...           ...       ...      ...         ...            ...
# 7115   128.002892         8  2.04560           1              1
# 7116   340.079432        24 -1.32270           5              9
# 7117  1114.554641        79  1.54710          13             20
# 7118   330.147689        21 -0.00030           0              5
# 7119   408.150365        28  3.35040           1              4
#
# [11716 rows x 9 columns]

# %%
df_melt = pd.melt(df, id_vars=['Source'], value_vars=['LogP', 'NumHDonors', 'NumHAcceptors'])
df_melt
# Out:
#          Source       variable     value
# 0          mtor           LogP   3.65160
# 1          mtor           LogP   4.59912
# 2          mtor           LogP   4.29930
# 3          mtor           LogP   3.65160
# 4          mtor           LogP   3.67590
# ...         ...            ...       ...
# 35143  drugbank  NumHAcceptors   1.00000
# 35144  drugbank  NumHAcceptors   9.00000
# 35145  drugbank  NumHAcceptors  20.00000
# 35146  drugbank  NumHAcceptors   5.00000
# 35147  drugbank  NumHAcceptors   4.00000
#
# [35148 rows x 3 columns]

# %%
sns.boxplot(y='NumAtoms', x='Source', data=df, showfliers=False)
# Out:
# <Axes: xlabel='Source', ylabel='NumAtoms'>

# %%
sns.boxplot(y='value', x='variable', hue='Source', data=df_melt, showfliers=False)
# Out:
# <Axes: xlabel='variable', ylabel='value'>

# %%
#sns.violinplot(y='value', x='variable', hue='Source', data=df_melt)
