ERROR: Explicit valence for atom # 27 N, 4, is greater than permitted
# [12:16:47] Can't kekulize mol.  Unkekulized atoms: 9 10 11 12 13 14 15 16 17
# [12:16:47] ERROR: Could not sanitize molecule ending on line 568252
# [12:16:47] ERROR: Can't kekulize mol.  Unkekulized atoms: 9 10 11 12 13 14 15 16 17
# [12:16:47] Can't kekulize mol.  Unkekulized atoms: 23 24 25 26 27
# [12:16:47] ERROR: Could not sanitize molecule ending on line 574645
# [12:16:47] ERROR: Can't kekulize mol.  Unkekulized atoms: 23 24 25 26 27
# [12:16:47] Can't kekulize mol.  Unkekulized atoms: 5 6 7 8 9
# [12:16:47] ERROR: Could not sanitize molecule ending on line 592639
# [12:16:47] ERROR: Can't kekulize mol.  Unkekulized atoms: 5 6 7 8 9
# [12:16:47] Explicit valence for atom # 15 O, 3, is greater than permitted
# [12:16:47] ERROR: Could not sanitize molecule ending on line 595909
# [12:16:47] ERROR: Explicit valence for atom # 15 O, 3, is greater than permitted
# [12:16:47] WARNING: could not find number of expected rings. Switching to an approximate ring finding algorithm.
# [12:16:47] Explicit valence for atom # 0 Br greater than permitted
# [12:16:47] ERROR: Could not sanitize molecule ending on line 599041
# [12:16:47] ERROR: Explicit valence for atom # 0 Br greater than permitted
# [12:16:47] Explicit valence for atom # 1 N, 4, is greater than permitted
# [12:16:47] ERROR: Could not sanitize molecule ending on line 601819
# [12:16:47] ERROR: Explicit valence for atom # 1 N, 4, is greater than permitted
# [12:16:47] Explicit valence for atom # 6 Be, 4, is greater than permitted
# [12:16:47] ERROR: Could not sanitize molecule ending on line 604427
# [12:16:47] ERROR: Explicit valence for atom # 6 Be, 4, is greater than permitted
# [12:16:47] Can't kekulize mol.  Unkekulized atoms: 4 5 6 7 8 9 10 11 12
# [12:16:47] ERROR: Could not sanitize molecule ending on line 604912
# [12:16:47] ERROR: Can't kekulize mol.  Unkekulized atoms: 4 5 6 7 8 9 10 11 12
# [12:16:47] Can't kekulize mol.  Unkekulized atoms: 5 6 7 8 9 10 11 12 13
# [12:16:47] ERROR: Could not sanitize molecule ending on line 616025
# [12:16:47] ERROR: Can't kekulize mol.  Unkekulized atoms: 5 6 7 8 9 10 11 12 13
# [12:16:47] Can't kekulize mol.  Unkekulized atoms: 1 2 3 5 6 7 8 9 10
# [12:16:47] ERROR: Could not sanitize molecule ending on line 623202
# [12:16:47] ERROR: Can't kekulize mol.  Unkekulized atoms: 1 2 3 5 6 7 8 9 10
# [12:16:47] Can't kekulize mol.  Unkekulized atoms: 5 6 7 8 9 10 11 12 13
# [12:16:47] ERROR: Could not sanitize molecule ending on line 628065
# [12:16:47] ERROR: Can't kekulize mol.  Unkekulized atoms: 5 6 7 8 9 10 11 12 13
# [12:16:47] Explicit valence for atom # 19 N greater than permitted
# [12:16:47] ERROR: Could not sanitize molecule ending on line 636938
# [12:16:47] ERROR: Explicit valence for atom # 19 N greater than permitted
# [12:16:47] Explicit valence for atom # 0 O, 3, is greater than permitted
# [12:16:47] ERROR: Could not sanitize molecule ending on line 640674
# [12:16:47] ERROR: Explicit valence for atom # 0 O, 3, is greater than permitted
# [12:16:47] Explicit valence for atom # 4 F, 2, is greater than permitted
# [12:16:47] ERROR: Could not sanitize molecule ending on line 645068
# [12:16:47] ERROR: Explicit valence for atom # 4 F, 2, is greater than permitted
# [12:16:47] Can't kekulize mol.  Unkekulized atoms: 0 1 2 4 5 6 7 8 9 10
# [12:16:47] ERROR: Could not sanitize molecule ending on line 659994
# [12:16:47] ERROR: Can't kekulize mol.  Unkekulized atoms: 0 1 2 4 5 6 7 8 9 10
# [12:16:47] Warning: ambiguous stereochemistry - linear bond arrangement - at atom 2 ignored
# [12:16:48] Warning: ambiguous stereochemistry - overlapping neighbors  - at atom 16 ignored
# [12:16:48] Warning: ambiguous stereochemistry - opposing bonds have opposite wedging - at atom 20 ignored.
# [12:16:48] Warning: ambiguous stereochemistry - opposing bonds have opposite wedging - at atom 20 ignored.
# [12:16:48] Explicit valence for atom # 0 Be, 3, is greater than permitted
# [12:16:48] ERROR: Could not sanitize molecule ending on line 995692
# [12:16:48] ERROR: Explicit valence for atom # 0 Be, 3, is greater than permitted
# [12:16:49] Explicit valence for atom # 0 C greater than permitted
# [12:16:49] ERROR: Could not sanitize molecule ending on line 1151592
# [12:16:49] ERROR: Explicit valence for atom # 0 C greater than permitted

# %%
pains = []

with open('../data/pains/p_l15.txt') as inp:
    for line in inp:
        pain, name = line.strip().split('\t')
        pains.append((Chem.MolFromSmarts(pain), name))

with open('../data/pains/p_m150.txt') as inp:
    for line in inp:
        pain, name = line.strip().split('\t')
        pains.append((Chem.MolFromSmarts(pain), name))

# %%
#pains

# %%
pains[0][0]

# %%
issues = []
for mol in drugbank:
    issue = []
    for id, (pain, name) in enumerate(pains):
        if mol.GetSubstructMatches(pain):
            issues.append(id)
        issues.append(issue)

# %%
problematic = [(id, [i]) for id, i in enumerate(issues) if i]

# %%
len(problematic)
# Out:
# 128

# %%
problematic
# Out:
# [(26338, [413]),
#  (60769, [418]),
#  (83715, [413]),
#  (90107, [4]),
#  (117292, [413]),
#  (125797, [417]),
#  (141944, [413]),
#  (163196, [414]),
#  (181062, [4]),
#  (213347, [413]),
#  (246923, [413]),
#  (289000, [414]),
#  (295822, [10]),
#  (312377, [414]),
#  (373152, [413]),
#  (380379, [414]),
#  (383779, [413]),
#  (385485, [418]),
#  (422881, [413]),
#  (431404, [10]),
#  (444138, [418]),
#  (448384, [413]),
#  (459860, [413]),
#  (473927, [29]),
#  (478988, [414]),
#  (483668, [418]),
#  (511911, [185]),
#  (531691, [414]),
#  (598882, [29]),
#  (617542, [413]),
#  (668543, [413]),
#  (714444, [413]),
#  (747596, [414]),
#  (782876, [418]),
#  (806277, [18]),
#  (845357, [422]),
#  (893799, [413]),
#  (895925, [413]),
#  (905701, [413]),
#  (943527, [413]),
#  (987728, [413]),
#  (1080388, [422]),
#  (1118206, [414]),
#  (1141156, [413]),
#  (1141582, [413]),
#  (1157733, [413]),
#  (1204484, [413]),
#  (1212135, [413]),
#  (1237212, [414]),
#  (1297138, [414]),
#  (1309039, [414]),
#  (1329469, [18]),
#  (1349012, [10]),
#  (1358342, [414]),
#  (1365567, [413]),
#  (1367693, [413]),
#  (1368970, [414]),
#  (1382146, [414]),
#  (1434005, [422]),
#  (1450998, [414]),
#  (1453974, [414]),
#  (1470978, [417]),
#  (1474379, [417]),
#  (1482026, [413]),
#  (1538127, [413]),
#  (1548328, [413]),
#  (1558533, [417]),
#  (1563630, [413]),
#  (1642256, [413]),
#  (1651608, [414]),
#  (1691984, [414]),
#  (1718760, [414]),
#  (1749785, [413]),
#  (1758286, [413]),
#  (1795479, [205]),
#  (1795690, [415]),
#  (1818214, [413]),
#  (1824590, [413]),
#  (1935516, [413]),
#  (1944867, [413]),
#  (2050269, [414]),
#  (2217936, [205]),
#  (2218147, [415]),
#  (2237271, [413]),
#  (2243244, [10]),
#  (2335028, [418]),
#  (2339274, [413]),
#  (2340975, [413]),
#  (2352452, [414]),
#  (2352881, [417]),
#  (2353303, [413]),
#  (2370729, [413]),
#  (2371155, [413]),
#  (2377107, [414]),
#  (2420463, [419]),
#  (2425988, [418]),
#  (2438310, [414]),
#  (2539045, [423]),
#  (2553934, [11]),
#  (2561993, [419]),
#  (2563689, [414]),
#  (2569640, [414]),
#  (2575166, [414]),
#  (2578142, [414]),
#  (2592593, [414]),
#  (2746872, [417]),
#  (2749849, [418]),
#  (2757495, [413]),
#  (2760047, [414]),
#  (2760473, [414]),
#  (2760899, [414]),
#  (2762175, [414]),
#  (2768134, [422]),
#  (2769826, [413]),
#  (2770252, [413]),
#  (2810629, [414]),
#  (2813605, [414]),
#  (2825932, [415]),
#  (2852728, [10]),
#  (2880124, [205]),
#  (2880335, [415]),
#  (2899459, [413]),
#  (2917314, [417]),
#  (2926237, [414]),
#  (2966612, [413]),
#  (3018038, [413]),
#  (3018464, [413]),
#  (3018890, [413])]

# %%
from collections import defaultdict

# %%
counts = defaultdict(lambda: 0)
for drug, lp in problematic:
    for p in lp:
        counts[p] += 1

# %%
print(counts.items())
len(counts.items())
# Out:
# dict_items([(413, 51), (418, 8), (4, 2), (417, 7), (414, 35), (10, 5), (29, 2), (185, 1), (18, 2), (422, 4), (205, 3), (415, 4), (419, 2), (423, 1), (11, 1)])
# 15

# %%
Draw.MolsToImage([pains[key][0] for key, count in counts.items()])
# Out:
# <PIL.Image.Image image mode=RGBA size=3000x200>

# %%
Draw.MolsToGridImage([pains[key][0] for key, count in counts.items()], molsPerRow = 5)

# %%
freq_pains = [(pains[key][0], pains[key][1], count) for key, count in counts.items()]

# %%
freq_pains
# Out:
# [(<rdkit.Chem.rdchem.Mol at 0x21a3233d7e0>, '<regId="quinone_A(370)">', 51),
#  (<rdkit.Chem.rdchem.Mol at 0x21a3233da10>, '<regId="anil_di_alk_C(246)">', 8),
#  (<rdkit.Chem.rdchem.Mol at 0x21a3223e340>, '<regId="styrene_A(13)">', 2),
#  (<rdkit.Chem.rdchem.Mol at 0x21a3233d8c0>, '<regId="anil_di_alk_B(251)">', 7),
#  (<rdkit.Chem.rdchem.Mol at 0x21a3233d770>, '<regId="azo_A(324)">', 35),
#  (<rdkit.Chem.rdchem.Mol at 0x21a3223e570>,
#   '<regId="keto_keto_beta_B(12)">',
#   5),
#  (<rdkit.Chem.rdchem.Mol at 0x21a3223edc0>, '<regId="styrene_B(8)">', 2),
#  (<rdkit.Chem.rdchem.Mol at 0x21a32333290>, '<regId="steroid_A(2)">', 1),
#  (<rdkit.Chem.rdchem.Mol at 0x21a3223e8f0>, '<regId="acyl_het_A(9)">', 2),
#  (<rdkit.Chem.rdchem.Mol at 0x21a3233db60>, '<regId="anil_di_alk_D(198)">', 4),
#  (<rdkit.Chem.rdchem.Mol at 0x21a32333bc0>, '<regId="quinone_D(2)">', 3),
#  (<rdkit.Chem.rdchem.Mol at 0x21a3233d850>, '<regId="imine_one_A(321)">', 4),
#  (<rdkit.Chem.rdchem.Mol at 0x21a3233d9a0>, '<regId="ene_rhod_A(235)">', 2),
#  (<rdkit.Chem.rdchem.Mol at 0x21a3233dbd0>,
#   '<regId="imine_one_isatin(189)">',
#   1),
#  (<rdkit.Chem.rdchem.Mol at 0x21a3223e650>, '<regId="keto_phenone_A(11)">', 1)]

# %%
#Draw.MolsToGridImage(freq_pains, molsPerRow = 5, legends=[f'{p[1]}>={p[2]}' for p in freq_pains])

# %%
smi = 'c1cc(F)ccc1Cl'
mol = Chem.MolFromSmiles(smi)
patt = Chem.MolFromSmarts('ClccccF')

# %%
def draw_mol_with_substr(mol, patt):
    hit_ats = list(mol.GetSubstructMatch(patt))
    hit_bonds = []
    for bond in patt.GetBonds():
       aid1 = hit_ats[bond.GetBeginAtomIdx()]
       aid2 = hit_ats[bond.GetEndAtomIdx()]
       hit_bonds.append(mol.GetBondBetweenAtoms(aid1,aid2).GetIdx())
    d = rdMolDraw2D.MolDraw2DSVG(500, 500) # or MolDraw2DCairo to get PNGs
    rdMolDraw2D.PrepareAndDrawMolecule(d, mol, highlightAtoms=hit_ats, highlightBonds=hit_bonds)

    d.FinishDrawing()
    return d

# %%
def visualize_match(structure, pattern):
    # GetSubstructMatches grabs all hits, GetSubstructMatch the first one it finds
    hits = structure.GetSubstructMatches(pattern)
    hit_atoms = set()
    hit_bonds = set()
    for hit in hits:
        hit_atoms.update(hit)
        hit_bonds.update([structure.GetBondBetweenAtoms(i, j).GetIdx()
                          for i, j in itertools.combinations(hit_atoms, 2)
                          if structure.GetBondBetweenAtoms(i, j)])
    d = rdMolDraw2D.MolDraw2DSVG(300,300)
    rdMolDraw2D.PrepareAndDrawMolecule(d, structure, highlightAtoms=hit_atoms, highlightBonds=hit_bonds)
    d.FinishDrawing()
    #return d.GetDrawingText()
    display(SVG(d.GetDrawingText()))

# %%
pict = visualize_match(mol, patt)

# %%
SVG(pict.GetDrawingText())

# %%
for drug, lp in problematic[:1]:
    print(drug)
    for p in lp:
        pict = visualize_match(drugbank[drug], pains[p][0])
        display(SVG(pict.GetDrawingText()))
# Out:
# 26338
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[93], line 4
#       2 print(drug)
#       3 for p in lp:
# ----> 4     pict = visualize_match(drugbank[drug], pains[p][0])
#       5     display(SVG(pict.GetDrawingText()))
#
# IndexError: list index out of range

# %%
len(drugbank)
# Out:
# 7120
